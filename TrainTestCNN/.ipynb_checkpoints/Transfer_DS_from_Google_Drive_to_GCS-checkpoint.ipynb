# %% [markdown]
# # Transfer new Wildfire Detection (Streamline2) datasets
# .....from my Google Drive to my Google Cloud Storage so that I can train on TPUs. This example shows how to transfer files from your Google Drive to a Google Cloud Storage project. We mount Google Drive using the google colab tools which requires authenticating in a separate brower window. Then we authenticate and connect our Google Cloud Storage project, list all buckets, and start copying files from Google Drive to our bucket.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import auth
auth.authenticate_user()

project_id = 'wildfire-detection'
# !gcloud config set project {project_id}
# !gsutil ls
# Out:
# Updated property [core/project].
# gs://streamline2/

# %%
bucket_name = 'streamline2'

# !gsutil -m cp -r /content/drive/My\ tinytrain/* gs://streamline2/
#/content/drive/My\ Drive/foo.txt
# !gsutil -m cp -r /content/drive/My\ Drive/Streamline2_data/* gs://streamline2/TrainStreamline2
# Out:
# Streaming output truncated to the last 5000 lines.
# Copying file:///content/drive/My Drive/Streamline2_data/smoke/om-e-mobo-c__2019-10-01T11;10;38_shift_flipped_3.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/My Drive/Streamline2_data/smoke/om-e-mobo-c__2019-10-01T11;10;38_shift_flipped_4.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/My Drive/Streamline2_data/smoke/om-e-mobo-c__2019-10-01T11;10;38_shift_flipped_2.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/My Drive/Streamline2_data/smoke/om-e-mobo-c__2019-10-01T11;14;39_shift_2.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/My Drive/Streamline2_data/smoke/om-e-mobo-c__2019-10-01T11;14;39_shift_flipped_1.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/My Drive/Streamline2_data/smoke/om-e-mobo-c__2019-10-01T11;12;37_shift_flipped_4.jpg [Content-Type=image/jpeg]...
# ...
