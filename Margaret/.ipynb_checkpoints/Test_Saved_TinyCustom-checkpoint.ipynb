# %% [markdown]
# This notebook loads a saved Wildfire Detection model, and steps through a directory of test image files passing each image to the model for classification. It prints each image, it's filename and its prediction. The model  uses Xception as a trained base, adds a head and trains with a dataset of 31,000 299x299 images - half containing smoke and half no smoke. It was created using Keras & TensorFlow.

# %%
# Setup
from tensorflow import keras
import tensorflow as tf
from keras.models import load_model
import numpy as np

# %%
# load saved model - NOTE: this takes a minute to load (it's 100mb)!
#model = tf.keras.models.load_model('MediumXception')
model = keras.models.load_model('LargeXception', compile=True)
# model = keras.models.load_model('MediumXception')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# xception (Functional)        (None, 10, 10, 2048)      20861480
# _________________________________________________________________
# flatten (Flatten)            (None, 204800)            0
# _________________________________________________________________
# dense (Dense)                (None, 256)               52429056
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 73,290,793
# Trainable params: 73,236,265
# Non-trainable params: 54,528
# _________________________________________________________________

# %%
def displayMyImage(name):
    image_path = name
    image_size = (299,299)
    img = cv2.imread(image_path) # with the OpenCV function imread(), the order of colors is BGR (blue, green, red).
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) # Converting BGR to RGB for Pillow
    display(Image.fromarray(img))

def getMyPrediction(name,model):
    image = tf.keras.preprocessing.image.load_img(name)
    input_arr = keras.preprocessing.image.img_to_array(image)
    input_arr = np.array([input_arr])  # Convert single image to a batch. 
    # Note: Xception expects a specific kind of input processing.
    # Before passing inputs to the model, call tf.keras.applications.xception.preprocess_input. 
    # It will scale scale input pixels between -1 and 1.
    x = preprocess_input(input_arr)
    predictions = model.predict(x)
    if predictions[0][0] <= 0.5:
        print("The image contains no smoke.")
    if predictions[0][0] > 0.5:
        print("The image contains smoke.")
    print(predictions[0][0])

# %%
import os
from PIL import Image
import cv2 
from IPython.display import display
from tensorflow.keras.applications.xception import preprocess_input
# Get a prediction on a single 299x299 image
# name = r'C:\Users\mthor\Bootcamp\Wildfire-Detection\Margaret\subimages\splitted_38.jpg' #split subimage
name = r'C:\Users\mthor\Unsynced Documents\HPWREN-FigLib_Output2\1528841646_+00660_centered_1.jpg'
displayMyImage(name)
print(name)
getMyPrediction(name,model)
# Out:
# <PIL.Image.Image image mode=RGB size=299x299 at 0x2069A390C70>
# C:\Users\mthor\Unsynced Documents\HPWREN-FigLib_Output2\1528841646_+00660_centered_1.jpg
# The image contains smoke.
# 1.0

# %%
 # Get a prediction on a single 299x299 image
name = r'C:\Users\mthor\Bootcamp\Wildfire-Detection\Margaret\hardtest\Whittier3-smoke.jpg'

displayMyImage(name)
print(name)
getMyPrediction(name,model)

# %%
# Get predictions on a directory of 299x299 images
import os
from PIL import Image
import cv2 
from IPython.display import display
from tensorflow.keras.applications.xception import preprocess_input


directory = r'C:\Users\mthor\Bootcamp\Wildfire-Detection\Margaret\easytest' # clear images that the model has likely seen
#directory = r'C:\Users\mthor\Bootcamp\Wildfire-Detection\Margaret\hardtest' # difficult, unseen images 
for filename in os.listdir(directory):
    if filename.endswith(".jpg"):
        name = os.path.join(directory, filename)
        displayMyImage(name)
        print(name)
        getMyPrediction(name,model)
    else:
        continue
# Out:
# <PIL.Image.Image image mode=RGB size=299x299 at 0x206963411F0>
# C:\Users\mthor\Bootcamp\Wildfire-Detection\Margaret\easytest\SmokeNoSmoke1.jpg
# The image contains smoke.
# 1.0
# <PIL.Image.Image image mode=RGB size=299x299 at 0x206979F05B0>
# C:\Users\mthor\Bootcamp\Wildfire-Detection\Margaret\easytest\SmokeNoSmoke10.jpg
# The image contains no smoke.
# 0.2784351
# <PIL.Image.Image image mode=RGB size=299x299 at 0x206934F96A0>
# C:\Users\mthor\Bootcamp\Wildfire-Detection\Margaret\easytest\SmokeNoSmoke11.jpg
# The image contains smoke.
# 1.0
# <PIL.Image.Image image mode=RGB size=299x299 at 0x206B2B0B640>
# C:\Users\mthor\Bootcamp\Wildfire-Detection\Margaret\easytest\SmokeNoSmoke12.jpg
# The image contains smoke.
# 1.0
# <PIL.Image.Image image mode=RGB size=299x299 at 0x206ADE024F0>
# C:\Users\mthor\Bootcamp\Wildfire-Detection\Margaret\easytest\SmokeNoSmoke2.jpg
# The image contains smoke.
# 0.58426064
# <PIL.Image.Image image mode=RGB size=299x299 at 0x20697A06520>
# C:\Users\mthor\Bootcamp\Wildfire-Detection\Margaret\easytest\SmokeNoSmoke3.jpg
# The image contains no smoke.
# 0.32335085
# <PIL.Image.Image image mode=RGB size=299x299 at 0x206B2A523D0>
# C:\Users\mthor\Bootcamp\Wildfire-Detection\Margaret\easytest\SmokeNoSmoke4.jpg
# The image contains no smoke.
# 0.0025574863
# <PIL.Image.Image image mode=RGB size=299x299 at 0x206ADE02BE0>
# C:\Users\mthor\Bootcamp\Wildfire-Detection\Margaret\easytest\SmokeNoSmoke5.jpg
# The image contains smoke.
# 1.0
# <PIL.Image.Image image mode=RGB size=299x299 at 0x20696396AF0>
# C:\Users\mthor\Bootcamp\Wildfire-Detection\Margaret\easytest\SmokeNoSmoke6.jpg
# The image contains smoke.
# 1.0
# <PIL.Image.Image image mode=RGB size=299x299 at 0x2069352C310>
# C:\Users\mthor\Bootcamp\Wildfire-Detection\Margaret\easytest\SmokeNoSmoke7.jpg
# The image contains no smoke.
# 1.534065e-08
# <PIL.Image.Image image mode=RGB size=299x299 at 0x2069351C400>
# C:\Users\mthor\Bootcamp\Wildfire-Detection\Margaret\easytest\SmokeNoSmoke8.jpg
# The image contains no smoke.
# 0.00039631128
# <PIL.Image.Image image mode=RGB size=299x299 at 0x206934F1D60>
# C:\Users\mthor\Bootcamp\Wildfire-Detection\Margaret\easytest\SmokeNoSmoke9.jpg
# The image contains no smoke.
# 0.027259648
