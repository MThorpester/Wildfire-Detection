# %% [markdown]
# This notebook creates a Keras Sequence model and then trains it on the Kaggle Cars dataset.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Wed May 26 19:12:44 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('To enable a high-RAM runtime, select the Runtime > "Change runtime type"')
  print('menu, and then select High-RAM in the Runtime shape dropdown. Then, ')
  print('re-execute this cell.')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 27.3 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
# Setup
# Imports
import os, warnings
import matplotlib.pyplot as plt
from matplotlib import gridspec

import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory

# Reproducability
def set_seed(seed=31415):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'
set_seed()

# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('image', cmap='magma')
warnings.filterwarnings("ignore") # to clean up output cells

# %%
## LOAD THE DATA ##
# Load training and validation sets
ds_train_ = image_dataset_from_directory(
    #'train',
    '/content/drive/MyDrive/tinyall',
    labels='inferred',
    label_mode='binary',
    validation_split=0.2,
    subset='training',
    seed=1337,
    image_size=[299, 299],
    interpolation='nearest',
    batch_size=64,
    shuffle=True,
)
ds_valid_ = image_dataset_from_directory(
    #'valid',
    '/content/drive/MyDrive/tinyall',
    labels='inferred',
    label_mode='binary',
    validation_split=0.2,
    subset='validation',
    seed=1337,
    image_size=[299, 299],
    interpolation='nearest',
    batch_size=64,
    shuffle=False,
)

# Data Pipeline
def convert_to_float(image, label):
    image = tf.image.convert_image_dtype(image, dtype=tf.float32)
    return image, label

AUTOTUNE = tf.data.experimental.AUTOTUNE
ds_train = (
    ds_train_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
ds_valid = (
    ds_valid_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
# Out:
# Found 130 files belonging to 2 classes.
# Using 104 files for training.
# Found 130 files belonging to 2 classes.
# Using 26 files for validation.

# %%
from tensorflow import keras
from tensorflow.keras import layers
# from tensorflow.keras.layers.experimental import preprocessing

# Define the model

model = keras.Sequential([
    layers.InputLayer(input_shape=[299, 299, 3]),
    
    # Data Augmentation
    # preprocessing.RandomContrast(factor=0.10),
    # preprocessing.RandomFlip(mode='horizontal'),
    # preprocessing.RandomRotation(factor=0.10),

    # Block One
    # layers.BatchNormalization(renorm=True),
    layers.Conv2D(filters=64, kernel_size=3, activation='relu', padding='same'),
    layers.MaxPool2D(),

    # Block Two
    layers.BatchNormalization(renorm=True),
    layers.Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'),
    layers.MaxPool2D(),

    # Block Three
    layers.BatchNormalization(renorm=True),
    layers.Conv2D(filters=256, kernel_size=3, activation='relu', padding='same'),
    layers.Conv2D(filters=256, kernel_size=3, activation='relu', padding='same'),
    layers.MaxPool2D(),

    # Head
    layers.BatchNormalization(renorm=True),
    layers.Flatten(),
    layers.Dense(8, activation='relu'),
    layers.Dense(1, activation='sigmoid'),
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 299, 299, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 149, 149, 64)      0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 149, 149, 64)      448
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 149, 149, 128)     73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 74, 74, 128)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 74, 74, 128)       896
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 74, 74, 256)       295168
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 74, 74, 256)       590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 37, 37, 256)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 37, 37, 256)       1792
# _________________________________________________________________
# flatten (Flatten)            (None, 350464)            0
# _________________________________________________________________
# dense (Dense)                (None, 8)                 2803720
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 3,767,761
# Trainable params: 3,765,521
# Non-trainable params: 2,240
# _________________________________________________________________

# %% [markdown]
# ## Train the Model
# We can train this model by compiling it with an optimizer along with a loss and metric appropriate for binary classification.

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(epsilon=0.01),
    loss='binary_crossentropy',
    metrics=['binary_accuracy']
)

history = model.fit(
    ds_train,
    validation_data=ds_valid,
    epochs=20,
    verbose=2,
)
# Out:
# Epoch 1/20
# 2/2 - 39s - loss: 0.6886 - binary_accuracy: 0.5962 - val_loss: 0.7354 - val_binary_accuracy: 0.0000e+00
# Epoch 2/20
# 2/2 - 1s - loss: 0.6746 - binary_accuracy: 0.5769 - val_loss: 0.8061 - val_binary_accuracy: 0.0000e+00
# Epoch 3/20
# 2/2 - 1s - loss: 0.6576 - binary_accuracy: 0.5769 - val_loss: 0.8512 - val_binary_accuracy: 0.0000e+00
# Epoch 4/20
# 2/2 - 1s - loss: 0.6388 - binary_accuracy: 0.5769 - val_loss: 0.8400 - val_binary_accuracy: 0.0000e+00
# Epoch 5/20
# 2/2 - 1s - loss: 0.6133 - binary_accuracy: 0.6442 - val_loss: 0.7781 - val_binary_accuracy: 0.1538
# Epoch 6/20
# 2/2 - 1s - loss: 0.5832 - binary_accuracy: 0.7596 - val_loss: 0.7089 - val_binary_accuracy: 0.4615
# Epoch 7/20
# 2/2 - 1s - loss: 0.5528 - binary_accuracy: 0.8462 - val_loss: 0.6918 - val_binary_accuracy: 0.5385
# Epoch 8/20
# 2/2 - 1s - loss: 0.5177 - binary_accuracy: 0.8654 - val_loss: 0.7135 - val_binary_accuracy: 0.5000
# Epoch 9/20
# 2/2 - 1s - loss: 0.4802 - binary_accuracy: 0.8558 - val_loss: 0.7176 - val_binary_accuracy: 0.5000
# Epoch 10/20
# 2/2 - 1s - loss: 0.4423 - binary_accuracy: 0.8558 - val_loss: 0.6572 - val_binary_accuracy: 0.6154
# Epoch 11/20
# 2/2 - 1s - loss: 0.4000 - binary_accuracy: 0.8942 - val_loss: 0.5595 - val_binary_accuracy: 0.7308
# Epoch 12/20
# 2/2 - 1s - loss: 0.3572 - binary_accuracy: 0.9135 - val_loss: 0.4651 - val_binary_accuracy: 0.7308
# Epoch 13/20
# 2/2 - 1s - loss: 0.3167 - binary_accuracy: 0.9231 - val_loss: 0.3980 - val_binary_accuracy: 0.8462
# Epoch 14/20
# 2/2 - 1s - loss: 0.2788 - binary_accuracy: 0.9423 - val_loss: 0.3625 - val_binary_accuracy: 0.8846
# Epoch 15/20
# 2/2 - 1s - loss: 0.2442 - binary_accuracy: 0.9519 - val_loss: 0.3393 - val_binary_accuracy: 0.8846
# Epoch 16/20
# 2/2 - 1s - loss: 0.2149 - binary_accuracy: 0.9423 - val_loss: 0.3072 - val_binary_accuracy: 0.8846
# Epoch 17/20
# 2/2 - 1s - loss: 0.1916 - binary_accuracy: 0.9423 - val_loss: 0.2636 - val_binary_accuracy: 0.8846
# Epoch 18/20
# 2/2 - 1s - loss: 0.1743 - binary_accuracy: 0.9423 - val_loss: 0.2214 - val_binary_accuracy: 0.9231
# Epoch 19/20
# 2/2 - 1s - loss: 0.1626 - binary_accuracy: 0.9519 - val_loss: 0.1934 - val_binary_accuracy: 0.9231
# Epoch 20/20
# 2/2 - 1s - loss: 0.1545 - binary_accuracy: 0.9615 - val_loss: 0.1814 - val_binary_accuracy: 0.9231

# %%
import pandas as pd

history_frame = pd.DataFrame(history.history)
history_frame.loc[:, ['loss', 'val_loss']].plot()
history_frame.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot();

# %%
# Save our trained model
model.save('/content/drive/MyDrive/TinyAllModel')
# Out:
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/TinyAllModel/assets

# %%
# reloaded_model = tf.keras.models.load_model('/content/drive/MyDrive/TinyAllModel')b
reloaded_model = tf.keras.models.load_model('TinyAllModel')

# %%
import visualkeras

model = reloaded_model

# visualkeras.layered_view(model).show() # display using your system viewer
# visualkeras.layered_view(model, to_file='output.png') # write to disk
# visualkeras.layered_view(model, to_file='output.png', legend=True).show() # write and show

visualkeras.layered_view(model, legend=True, )
# Out:
# <PIL.Image.Image image mode=RGBA size=803x1227 at 0x1DFD3364670>

# %%
# specify the image to be displayed and classified
# image_path = '/content/drive/MyDrive/SmokeNoSmoke1.jpg'
image_path = 'SmokeNoSmoke12.jpg'
image_size = (299,299)
from PIL import Image
import cv2 
from IPython.display import display

img = cv2.imread(image_path) # with the OpenCV function imread(), the order of colors is BGR (blue, green, red).
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) # Converting BGR to RGB for Pillow
display(Image.fromarray(img))
# Out:
# <PIL.Image.Image image mode=RGB size=299x299 at 0x1F82D68F8B0>

# %%
# 2 different ways to prepare the image and pass it for prediction.....here is the first
from tensorflow import keras
image = tf.keras.preprocessing.image.load_img(image_path)
input_arr = keras.preprocessing.image.img_to_array(image)
input_arr = np.array([input_arr])  # Convert single image to a batch.
predictions = reloaded_model.predict(input_arr)

if predictions[0][0] == 0:
    print("The image contains no smoke.")

if predictions[0][0] == 1:
    print("The image contains smoke.")
# Out:
# The image contains no smoke.

# %%
# 2 different ways to prepare the image and pass it for prediction.....here is the second
img = keras.preprocessing.image.load_img(
    image_path, target_size=image_size   
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # Create batch axis

predictions = reloaded_model.predict(img_array)
score = predictions[0]
print(
    "This image is %.2f percent nosmoke and %.2f percent nosmoke."
    % (100 * (1 - score), 100 * score)
)
# Out:
# This image is 100.00 percent nosmoke and 0.00 percent nosmoke.

# %%
dot_img_file = 'model_1.png'
tf.keras.utils.plot_model(reloaded_model, to_file=dot_img_file, show_shapes=True, show_layer_names=True)
